# %%
import neat
import pandas as pd
import numpy as np
import time

cardio_dataset = pd.read_csv('3-cleaned-normalized.csv')

dataset_size = cardio_dataset.shape[0]
max_items = 3200

# Load configuration.
config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                     neat.DefaultSpeciesSet, neat.DefaultStagnation,
                     'neat-config-cardio')



# Create the population, which is the top-level object for a NEAT run.
p = neat.Population(config)

# Add a stdout reporter to show progress in the terminal.
p.add_reporter(neat.StdOutReporter(False))

def load_data(num_items, num_features="all", random_state=1):    
    cardio = cardio_dataset.sample(n=num_items, random_state=random_state)
    d = cardio.iloc[:,0:11]
    t = cardio['cardio']
    data = d.values
    target = t.values
    return data, target

class DynamicRunner:
    
    def __init__(self):
        self.data = None
        self.target = None
    
    def eval_genomes(self, genomes, config):
        for genome_id, genome in genomes:
            genome.fitness = 1.0
            net = neat.nn.FeedForwardNetwork.create(genome, config)
            # print(len(self.data), len(self.target))
            for xi, xo in zip(self.data, self.target):
                output = net.activate(xi)
                genome.fitness -= (abs(output[0] - xo))/len(self.target)
    
    def run_dynamic(self, max_items):
    
        items = 100
        item_incr = 100
        iters_single = 5
        iters_incr = 20
        iters_max = 200
        
        while items <= max_items:
            self.data, self.target = load_data(num_items=items)
        
            print("\n\n", len(self.data), len(self.target), "\n\n")
        
            winner = p.run(self.eval_genomes,iters_single)
            print('\nBest genome:\n{!s}'.format(winner))
            
            items *= 2
            iters_single *= 2
    
        return winner

    def results(self, winner, max_items):
                      
        # Show output of the most fit genome against training data.
        print('\nOutput:')
        winner_net = neat.nn.FeedForwardNetwork.create(winner, config)
        predictions = []
        for xi, xo in zip(self.data, self.target):
            output = winner_net.activate(xi)
            predictions.append(round(output[0]))
            # print("  input {!r}, expected output {!r}, got {!r}".format(xi, xo, output))
    
        acc = sum([abs(predictions[i]-self.target[i]) for i in range(len(self.target))])
        acc = 1 - acc/len(self.target)
        print('\nTraining Accuracy:', acc)

        data, target = load_data(num_items=max_items)
        predictions = []
        for xi, xo in zip(data, target):
            output = winner_net.activate(xi)
            predictions.append(round(output[0]))

        acc = sum([abs(predictions[i]-target[i]) for i in range(len(target))])
        acc = 1 - acc/len(target)
        print('\nTesting Accuracy:', acc)        


start = time.time()
d = DynamicRunner()
winner = d.run_dynamic(max_items)
d.results(winner, dataset_size)
end = time.time()
print("\nTotal time:", end-start, "seconds")
# Out:
#  100 100
#
#
#
#  ****** Running generation 0 ******
#
# Population's average fitness: 0.49896 stdev: 0.04927
# Best fitness: 0.63885 - size: (1, 11) - species 1 - id 31
# Average adjusted fitness: 0.121
# Mean genetic distance 1.119, standard deviation 0.391
# Population of 150 members in 1 species
# Total extinctions: 0
# Generation time: 0.180 sec
#
#  ****** Running generation 1 ******
#
# Population's average fitness: 0.52905 stdev: 0.04288
# Best fitness: 0.63899 - size: (1, 9) - species 1 - id 228
# Average adjusted fitness: 0.139
# Mean genetic distance 1.163, standard deviation 0.350
# Population of 150 members in 1 species
# Total extinctions: 0
# Generation time: 0.193 sec (0.187 average)
#
#  ****** Running generation 2 ******
#
# Population's average fitness: 0.54629 stdev: 0.05082
# Best fitness: 0.72085 - size: (1, 8) - species 1 - id 416
# Average adjusted fitness: 0.102
# Mean genetic distance 1.276, standard deviation 0.390
# Population of 150 members in 1 species
# Total extinctions: 0
# Generation time: 0.233 sec (0.202 average)
#
#  ****** Running generation 3 ******
#
# Population's average fitness: 0.55886 stdev: 0.05437
# Best fitness: 0.72085 - size: (1, 8) - species 1 - id 416
# Average adjusted fitness: 0.111
# Mean genetic distance 1.511, standard deviation 0.377
# Population of 150 members in 1 species
# Total extinctions: 0
# Generation time: 0.189 sec (0.199 average)
#
#  ****** Running generation 4 ******
#
# Population's average fitness: 0.55579 stdev: 0.06310
# Best fitness: 0.72190 - size: (2, 10) - species 1 - id 671
# Average adjusted fitness: 0.137
# Mean genetic distance 1.772, standard deviation 0.413
# Population of 150 members in 1 species
# Total extinctions: 0
# Generation time: 0.206 sec (0.200 average)
#
# Best genome:
# Key: 671
# Fitness: 0.7219042394233044
# Nodes:
# 	0 DefaultNodeGene(key=0, bias=-2.8235312106937416, response=1.0, activation=sigmoid, aggregation=sum)
# 	6 DefaultNodeGene(key=6, bias=-1.5918005081579856, response=1.0, activation=sigmoid, aggregation=sum)
# Connections:
# 	DefaultConnectionGene(key=(-10, 0), weight=-0.5793182904479681, enabled=False)
# 	DefaultConnectionGene(key=(-9, 0), weight=-2.6612070517594506, enabled=True)
# 	DefaultConnectionGene(key=(-8, 0), weight=0.0187556980399477, enabled=True)
# 	DefaultConnectionGene(key=(-8, 6), weight=-0.15702182928186048, enabled=True)
# 	DefaultConnectionGene(key=(-7, 0), weight=1.8277146522068257, enabled=True)
# 	DefaultConnectionGene(key=(-6, 0), weight=1.732804086967783, enabled=True)
# 	DefaultConnectionGene(key=(-5, 0), weight=1.0399990688012544, enabled=True)
# 	DefaultConnectionGene(key=(-4, 0), weight=-0.1684573726455426, enabled=True)
# 	DefaultConnectionGene(key=(-3, 0), weight=-0.994145325041013, enabled=True)
# 	DefaultConnectionGene(key=(-2, 0), weight=1.5189473911108493, enabled=False)
# 	DefaultConnectionGene(key=(-2, 6), weight=1.8153190987848613, enabled=True)
# 	DefaultConnectionGene(key=(6, 0), weight=-0.03693877850520322, enabled=True)
#
#
#  200 200
#
#
#
#  ****** Running generation 5 ******
#
# Population's average fitness: 0.53785 stdev: 0.04703
# Best fitness: 0.67371 - size: (2, 10) - species 1 - id 671
# Average adjusted fitness: 0.072
# Mean genetic distance 1.849, standard deviation 0.423
# Population of 150 members in 1 species
# Total extinctions: 0
# Generation time: 0.379 sec (0.230 average)
#
#  ****** Running generation 6 ******
#
# Population's average fitness: 0.56113 stdev: 0.05620
# Best fitness: 0.71169 - size: (2, 8) - species 1 - id 904
# Average adjusted fitness: 0.086
# Mean genetic distance 1.970, standard deviation 0.412
# Population of 150 members in 1 species
# Total extinctions: 0
# Generation time: 0.335 sec (0.245 average)
#
#  ****** Running generation 7 ******
#
# Population's average fitness: 0.56532 stdev: 0.06391
# Best fitness: 0.71239 - size: (1, 4) - species 1 - id 1072
# Average adjusted fitness: 0.199
# Mean genetic distance 2.102, standard deviation 0.391
# Population of 150 members in 2 species
# Total extinctions: 0
# Generation time: 0.394 sec (0.264 average)
#
#  ****** Running generation 8 ******
#
# Population's average fitness: 0.57419 stdev: 0.06976
# Best fitness: 0.72057 - size: (2, 4) - species 2 - id 1310
# Average adjusted fitness: 0.100
# Mean genetic distance 2.116, standard deviation 0.387
# Population of 150 members in 2 species
# Total extinctions: 0
# Generation time: 0.319 sec (0.270 average)
#
#  ****** Running generation 9 ******
#
# Population's average fitness: 0.57984 stdev: 0.06695
# Best fitness: 0.72057 - size: (2, 4) - species 2 - id 1310
# Average adjusted fitness: 0.090
# Mean genetic distance 2.063, standard deviation 0.416
# Population of 150 members in 2 species
# Total extinctions: 0
# Generation time: 0.339 sec (0.277 average)
#
#  ****** Running generation 10 ******
#
# Population's average fitness: 0.58952 stdev: 0.06803
# Best fitness: 0.72057 - size: (2, 4) - species 2 - id 1310
# Average adjusted fitness: 0.099
# Mean genetic distance 1.885, standard deviation 0.430
# Population of 150 members in 2 species
# Total extinctions: 0
# Generation time: 0.313 sec (0.290 average)
#
#  ****** Running generation 11 ******
#
# Population's average fitness: 0.59435 stdev: 0.07623
# Best fitness: 0.72057 - size: (2, 4) - species 2 - id 1310
# Average adjusted fitness: 0.148
# Mean genetic distance 1.788, standard deviation 0.460
# Population of 150 members in 2 species
# Total extinctions: 0
# Generation time: 0.289 sec (0.300 average)
#
#  ****** Running generation 12 ******
#
# Population's average fitness: 0.58052 stdev: 0.07244
# Best fitness: 0.72057 - size: (2, 4) - species 2 - id 1310
# Average adjusted fitness: 0.100
# Mean genetic distance 1.820, standard deviation 0.464
# Population of 150 members in 2 species
# Total extinctions: 0
# Generation time: 0.277 sec (0.304 average)
#
#  ****** Running generation 13 ******
#
# Population's average fitness: 0.58549 stdev: 0.07446
# Best fitness: 0.72978 - size: (1, 6) - species 2 - id 1983
# Average adjusted fitness: 0.108
# Mean genetic distance 1.872, standard deviation 0.481
# Population of 150 members in 2 species
# Total extinctions: 0
# Generation time: 0.290 sec (0.314 average)
#
#  ****** Running generation 14 ******
#
# Population's average fitness: 0.57868 stdev: 0.07204
# Best fitness: 0.72978 - size: (1, 6) - species 2 - id 1983
# Average adjusted fitness: 0.092
# Mean genetic distance 1.964, standard deviation 0.512
# Population of 150 members in 2 species
# Total extinctions: 0
# Generation time: 0.273 sec (0.321 average)
#
# Best genome:
# Key: 1983
# Fitness: 0.7297833494334919
# Nodes:
# 	0 DefaultNodeGene(key=0, bias=-2.668188639853139, response=1.0, activation=sigmoid, aggregation=sum)
# Connections:
# 	DefaultConnectionGene(key=(-10, 0), weight=-1.83672850480986, enabled=True)
# 	DefaultConnectionGene(key=(-9, 0), weight=0.16573156615523169, enabled=True)
# 	DefaultConnectionGene(key=(-8, 0), weight=1.9639267409438088, enabled=False)
# 	DefaultConnectionGene(key=(-7, 0), weight=1.4385666213513768, enabled=True)
# 	DefaultConnectionGene(key=(-5, 0), weight=3.7537927000033218, enabled=True)
# 	DefaultConnectionGene(key=(-4, 0), weight=0.21803961747787792, enabled=True)
# 	DefaultConnectionGene(key=(-3, 0), weight=-1.0354021996692557, enabled=True)
# 	DefaultConnectionGene(key=(-2, 0), weight=1.3944101891257143, enabled=False)
#
#
#  400 400
#
#
#
#  ****** Running generation 15 ******
#
# Population's average fitness: 0.58109 stdev: 0.07258
# Best fitness: 0.69944 - size: (2, 3) - species 1 - id 2214
# Average adjusted fitness: 0.092
# Mean genetic distance 1.947, standard deviation 0.453
# Population of 150 members in 2 species
# Total extinctions: 0
# Generation time: 0.531 sec (0.336 average)
#
#  ****** Running generation 16 ******
#
# Population's average fitness: 0.58474 stdev: 0.06913
# Best fitness: 0.70504 - size: (3, 5) - species 2 - id 2451
# Average adjusted fitness: 0.081
# Mean genetic distance 1.846, standard deviation 0.457
# Population of 150 members in 2 species
# Total extinctions: 0
# Generation time: 0.507 sec (0.353 average)
#
#  ****** Running generation 17 ******
#
# Population's average fitness: 0.58795 stdev: 0.07140
# Best fitness: 0.70779 - size: (2, 3) - species 2 - id 2575
# Average adjusted fitness: 0.092
# Mean genetic distance 1.776, standard deviation 0.470
# Population of 150 members in 2 species
# Total extinctions: 0
# Generation time: 0.535 sec (0.367 average)
#
#  ****** Running generation 18 ******
# Population's average fitness: 0.58587 stdev: 0.07618
# Best fitness: 0.70865 - size: (3, 5) - species 2 - id 2765
# Average adjusted fitness: 0.173
# Mean genetic distance 1.864, standard deviation 0.458
# Population of 150 members in 2 species
# Total extinctions: 0
# Generation time: 0.518 sec (0.387 average)
#
#  ****** Running generation 19 ******
#
# Population's average fitness: 0.58401 stdev: 0.07790
# Best fitness: 0.70865 - size: (3, 5) - species 2 - id 2765
# Average adjusted fitness: 0.112
# Mean genetic distance 1.838, standard deviation 0.457
# Population of 150 members in 2 species
# Total extinctions: 0
# Generation time: 0.521 sec (0.405 average)
#
#  ****** Running generation 20 ******
#
# Population's average fitness: 0.60302 stdev: 0.07496
# Best fitness: 0.70865 - size: (3, 5) - species 2 - id 2765
# Average adjusted fitness: 0.126
# Mean genetic distance 1.801, standard deviation 0.560
# Population of 150 members in 2 species
# Total extinctions: 0
# Generation time: 0.513 sec (0.425 average)
#
#  ****** Running generation 21 ******
#
# Population's average fitness: 0.58769 stdev: 0.07730
# Best fitness: 0.70978 - size: (4, 7) - species 2 - id 3216
# Average adjusted fitness: 0.163
# Mean genetic distance 1.716, standard deviation 0.616
# Population of 150 members in 2 species
# Total extinctions: 0
# Generation time: 0.527 sec (0.449 average)
#
#  ****** Running generation 22 ******
#
# Population's average fitness: 0.59636 stdev: 0.07410
# Best fitness: 0.71028 - size: (2, 2) - species 2 - id 3369
# Average adjusted fitness: 0.101
# Mean genetic distance 1.869, standard deviation 0.620
# Population of 150 members in 3 species
# Total extinctions: 0
# Generation time: 0.540 sec (0.475 average)
#
#  ****** Running generation 23 ******
#
# Population's average fitness: 0.60666 stdev: 0.07697
# Best fitness: 0.71028 - size: (2, 2) - species 2 - id 3369
# Average adjusted fitness: 0.114
# Mean genetic distance 2.151, standard deviation 0.654
# Population of 151 members in 3 species
# Total extinctions: 0
# Generation time: 0.513 sec (0.498 average)
#
#  ****** Running generation 24 ******
#
# Population's average fitness: 0.59621 stdev: 0.07547
# Best fitness: 0.71173 - size: (2, 2) - species 3 - id 3597
# Average adjusted fitness: 0.098
# Mean genetic distance 2.150, standard deviation 0.576
# Population of 150 members in 3 species
# Total extinctions: 0
# Generation time: 0.555 sec (0.526 average)
#
#  ****** Running generation 25 ******
#
# Population's average fitness: 0.59902 stdev: 0.07890
# Best fitness: 0.71309 - size: (2, 6) - species 3 - id 3810
# Average adjusted fitness: 0.103
# Mean genetic distance 2.083, standard deviation 0.571
# Population of 151 members in 3 species
# Total extinctions: 0
# Generation time: 0.540 sec (0.527 average)
#
#  ****** Running generation 26 ******
#
# Population's average fitness: 0.59601 stdev: 0.08002
# Best fitness: 0.71309 - size: (2, 6) - species 3 - id 3810
# Average adjusted fitness: 0.098
# Mean genetic distance 2.025, standard deviation 0.562
# Population of 150 members in 3 species
# Total extinctions: 0
# Generation time: 0.544 sec (0.530 average)
#
#  ****** Running generation 27 ******
#
# Population's average fitness: 0.59786 stdev: 0.08131
# Best fitness: 0.71484 - size: (2, 4) - species 3 - id 4087
# Average adjusted fitness: 0.100
# Mean genetic distance 1.940, standard deviation 0.542
# Population of 151 members in 3 species
# Total extinctions: 0
# Generation time: 0.549 sec (0.532 average)
#
#  ****** Running generation 28 ******
#
# Population's average fitness: 0.60710 stdev: 0.07920
# Best fitness: 0.71484 - size: (2, 4) - species 3 - id 4087
# Average adjusted fitness: 0.112
# Mean genetic distance 2.049, standard deviation 0.575
# Population of 150 members in 3 species
# Total extinctions: 0
# Generation time: 0.544 sec (0.535 average)
#
#  ****** Running generation 29 ******
#
# Population's average fitness: 0.60189 stdev: 0.08650
# Best fitness: 0.71577 - size: (2, 4) - species 3 - id 4376
# Average adjusted fitness: 0.065
# Mean genetic distance 2.163, standard deviation 0.682
# Population of 150 members in 4 species
# Total extinctions: 0
# Generation time: 0.579 sec (0.540 average)
#
#  ****** Running generation 30 ******
#
# Population's average fitness: 0.60114 stdev: 0.08248
# Best fitness: 0.71635 - size: (2, 3) - species 5 - id 4512
# Average adjusted fitness: 0.115
# Mean genetic distance 2.304, standard deviation 0.662
# Population of 150 members in 4 species
# Total extinctions: 0
# Generation time: 0.565 sec (0.546 average)
#
#  ****** Running generation 31 ******
#
# Population's average fitness: 0.60560 stdev: 0.08343
# Best fitness: 0.71844 - size: (2, 4) - species 5 - id 4593
# Average adjusted fitness: 0.095
# Mean genetic distance 2.283, standard deviation 0.599
# Population of 149 members in 4 species
# Total extinctions: 0
# Generation time: 0.556 sec (0.549 average)
#
#  ****** Running generation 32 ******
#
# Population's average fitness: 0.60552 stdev: 0.08542
# Best fitness: 0.71844 - size: (2, 4) - species 5 - id 4593
# Average adjusted fitness: 0.119
# Mean genetic distance 2.295, standard deviation 0.643
# Population of 150 members in 4 species
# Total extinctions: 0
# Generation time: 0.565 sec (0.551 average)
#
#  ****** Running generation 33 ******
#
# Population's average fitness: 0.60336 stdev: 0.08320
# Best fitness: 0.71844 - size: (2, 4) - species 3 - id 4593
# Average adjusted fitness: 0.107
# Mean genetic distance 2.275, standard deviation 0.710
# Population of 151 members in 4 species
# Total extinctions: 0
# Generation time: 0.573 sec (0.557 average)
#
#  ****** Running generation 34 ******
#
# Population's average fitness: 0.61492 stdev: 0.07904
# Best fitness: 0.71844 - size: (2, 4) - species 3 - id 4593
# Average adjusted fitness: 0.116
# Mean genetic distance 2.408, standard deviation 0.725
# Population of 150 members in 4 species
# Total extinctions: 0
# Generation time: 0.577 sec (0.559 average)
#
# Best genome:
# Key: 4593
# Fitness: 0.7184385503722704
# Nodes:
# 	0 DefaultNodeGene(key=0, bias=-4.8128169917828245, response=1.0, activation=sigmoid, aggregation=sum)
# 	243 DefaultNodeGene(key=243, bias=-0.11476383629241171, response=1.0, activation=sigmoid, aggregation=sum)
# Connections:
# 	DefaultConnectionGene(key=(-10, 0), weight=-0.9510569165570627, enabled=True)
# 	DefaultConnectionGene(key=(-7, 0), weight=1.7374085274425182, enabled=True)
# 	DefaultConnectionGene(key=(-5, 0), weight=7.343588140256035, enabled=True)
# 	DefaultConnectionGene(key=(-2, 243), weight=-0.006814983612831461, enabled=False)
# 	DefaultConnectionGene(key=(0, 243), weight=0.7844442233589892, enabled=True)
#
#
#  800 800
#
#
#
#  ****** Running generation 35 ******
#
# Population's average fitness: 0.60023 stdev: 0.07292
# Best fitness: 0.69156 - size: (2, 5) - species 3 - id 5149
# Average adjusted fitness: 0.102
# Mean genetic distance 2.485, standard deviation 0.839
# Population of 150 members in 3 species
# Total extinctions: 0
# Generation time: 1.137 sec (0.619 average)
#
#  ****** Running generation 36 ******
#
# Population's average fitness: 0.59421 stdev: 0.07210
# Best fitness: 0.69156 - size: (2, 5) - species 3 - id 5149
# Average adjusted fitness: 0.094
# Mean genetic distance 2.529, standard deviation 0.766
# Population of 150 members in 3 species
# Total extinctions: 0
# Generation time: 1.163 sec (0.681 average)
#
#  ****** Running generation 37 ******
#
# Population's average fitness: 0.58608 stdev: 0.07250
# Best fitness: 0.69156 - size: (2, 5) - species 5 - id 5149
# Average adjusted fitness: 0.088
# Mean genetic distance 2.438, standard deviation 0.707
# Population of 150 members in 3 species
# Total extinctions: 0
# Generation time: 1.211 sec (0.747 average)
#
#  ****** Running generation 38 ******
#
# Population's average fitness: 0.59473 stdev: 0.07416
# Best fitness: 0.69156 - size: (2, 5) - species 5 - id 5149
# Average adjusted fitness: 0.105
# Mean genetic distance 2.596, standard deviation 0.726
# Population of 149 members in 5 species
# Total extinctions: 0
# Generation time: 1.195 sec (0.812 average)
#
#  ****** Running generation 39 ******
#
# Population's average fitness: 0.60307 stdev: 0.07505
# Best fitness: 0.69156 - size: (2, 5) - species 5 - id 5149
# Average adjusted fitness: 0.138
# Mean genetic distance 2.708, standard deviation 0.699
# Population of 149 members in 5 species
# Total extinctions: 0
# Generation time: 1.178 sec (0.872 average)
#
#  ****** Running generation 40 ******
#
# Population's average fitness: 0.60148 stdev: 0.07686
# Best fitness: 0.69156 - size: (2, 5) - species 5 - id 5149
# Average adjusted fitness: 0.164
# Mean genetic distance 2.656, standard deviation 0.758
# Population of 150 members in 7 species
# Total extinctions: 0
# Generation time: 1.198 sec (0.935 average)
#
#  ****** Running generation 41 ******
# Population's average fitness: 0.59906 stdev: 0.07468
# Best fitness: 0.69156 - size: (2, 5) - species 5 - id 5149
# Average adjusted fitness: 0.075
# Mean genetic distance 2.687, standard deviation 0.772
# Population of 151 members in 7 species
# Total extinctions: 0
# Generation time: 1.184 sec (0.998 average)
#
#  ****** Running generation 42 ******
#
# Population's average fitness: 0.60390 stdev: 0.07763
# Best fitness: 0.69362 - size: (2, 6) - species 5 - id 6205
# Average adjusted fitness: 0.091
# Mean genetic distance 2.706, standard deviation 0.768
# Population of 150 members in 7 species
# Total extinctions: 0
# Generation time: 1.133 sec (1.055 average)
#
#  ****** Running generation 43 ******
#
# Population's average fitness: 0.60258 stdev: 0.07753
# Best fitness: 0.69362 - size: (2, 6) - species 5 - id 6205
# Average adjusted fitness: 0.093
# Mean genetic distance 2.626, standard deviation 0.804
# Population of 149 members in 7 species
# Total extinctions: 0
# Generation time: 1.112 sec (1.109 average)
#
#  ****** Running generation 44 ******
#
# Population's average fitness: 0.59942 stdev: 0.07782
# Best fitness: 0.69362 - size: (2, 6) - species 5 - id 6205
# Average adjusted fitness: 0.091
# Mean genetic distance 2.623, standard deviation 0.791
# Population of 149 members in 8 species
# Total extinctions: 0
# Generation time: 1.349 sec (1.186 average)
#
#  ****** Running generation 45 ******
#
# Population's average fitness: 0.60362 stdev: 0.07978
# Best fitness: 0.69362 - size: (2, 6) - species 5 - id 6205
# Average adjusted fitness: 0.082
# Mean genetic distance 2.804, standard deviation 0.810
# Population of 149 members in 8 species
# Total extinctions: 0
# Generation time: 1.375 sec (1.210 average)
#
#  ****** Running generation 46 ******
#
# Population's average fitness: 0.59663 stdev: 0.07636
# Best fitness: 0.69362 - size: (2, 6) - species 5 - id 6205
# Average adjusted fitness: 0.082
# Mean genetic distance 2.846, standard deviation 0.784
# Population of 150 members in 8 species
# Total extinctions: 0
# Generation time: 1.369 sec (1.230 average)
#
#  ****** Running generation 47 ******
#
# Population's average fitness: 0.58520 stdev: 0.08057
# Best fitness: 0.69362 - size: (2, 6) - species 5 - id 6205
# Average adjusted fitness: 0.075
# Mean genetic distance 2.764, standard deviation 0.740
# Population of 148 members in 8 species
# Total extinctions: 0
# Generation time: 1.327 sec (1.242 average)
#
#  ****** Running generation 48 ******
#
# Population's average fitness: 0.59383 stdev: 0.07422
# Best fitness: 0.69362 - size: (2, 6) - species 5 - id 6205
# Average adjusted fitness: 0.093
# Mean genetic distance 2.664, standard deviation 0.764
# Population of 150 members in 8 species
# Total extinctions: 0
# Generation time: 1.364 sec (1.259 average)
#
#  ****** Running generation 49 ******
#
# Population's average fitness: 0.58882 stdev: 0.08048
# Best fitness: 0.69362 - size: (2, 6) - species 5 - id 6205
# Average adjusted fitness: 0.105
# Mean genetic distance 2.577, standard deviation 0.711
# Population of 148 members in 8 species
# Total extinctions: 0
# Generation time: 1.350 sec (1.276 average)
#
#  ****** Running generation 50 ******
#
# Population's average fitness: 0.58441 stdev: 0.07735
# Best fitness: 0.69362 - size: (2, 6) - species 5 - id 6205
# Average adjusted fitness: 0.099
# Mean genetic distance 2.538, standard deviation 0.686
# Population of 149 members in 8 species
# Total extinctions: 0
# Generation time: 1.338 sec (1.290 average)
#
#  ****** Running generation 51 ******
#
# Population's average fitness: 0.58925 stdev: 0.07728
# Best fitness: 0.69362 - size: (2, 6) - species 5 - id 6205
# Average adjusted fitness: 0.083
# Mean genetic distance 2.602, standard deviation 0.726
# Population of 149 members in 8 species
# Total extinctions: 0
# Generation time: 1.366 sec (1.308 average)
#
#  ****** Running generation 52 ******
#
# Population's average fitness: 0.59322 stdev: 0.07900
# Best fitness: 0.69419 - size: (3, 10) - species 5 - id 7562
# Average adjusted fitness: 0.153
# Mean genetic distance 2.587, standard deviation 0.686
# Population of 150 members in 8 species
# Total extinctions: 0
# Generation time: 1.324 sec (1.327 average)
#
#  ****** Running generation 53 ******
#
# Population's average fitness: 0.60539 stdev: 0.07853
# Best fitness: 0.69419 - size: (3, 10) - species 5 - id 7562
# Average adjusted fitness: 0.103
# Mean genetic distance 2.561, standard deviation 0.676
# Population of 148 members in 8 species
# Total extinctions: 0
# Generation time: 1.391 sec (1.355 average)
#
#  ****** Running generation 54 ******
#
# Population's average fitness: 0.59319 stdev: 0.07839
# Best fitness: 0.69419 - size: (3, 10) - species 5 - id 7562
# Average adjusted fitness: 0.101
# Mean genetic distance 2.575, standard deviation 0.730
# Population of 148 members in 8 species
# Total extinctions: 0
# Generation time: 1.355 sec (1.356 average)
#
#  ****** Running generation 55 ******
#
# Population's average fitness: 0.60629 stdev: 0.07147
# Best fitness: 0.69419 - size: (3, 10) - species 5 - id 7562
# Average adjusted fitness: 0.099
# Mean genetic distance 2.600, standard deviation 0.693
# Population of 149 members in 8 species
# Total extinctions: 0
# Generation time: 1.375 sec (1.356 average)
#
#  ****** Running generation 56 ******
#
# Population's average fitness: 0.59829 stdev: 0.07863
# Best fitness: 0.69419 - size: (3, 10) - species 5 - id 7562
# Average adjusted fitness: 0.093
# Mean genetic distance 2.602, standard deviation 0.745
# Population of 149 members in 8 species
# Total extinctions: 0
# Generation time: 1.375 sec (1.356 average)
#
#  ****** Running generation 57 ******
#
# Population's average fitness: 0.59039 stdev: 0.07919
# Best fitness: 0.69419 - size: (3, 10) - species 5 - id 7562
# Average adjusted fitness: 0.085
# Mean genetic distance 2.638, standard deviation 0.735
# Population of 151 members in 7 species
# Total extinctions: 0
# Generation time: 1.397 sec (1.364 average)
#
#  ****** Running generation 58 ******
#
# Population's average fitness: 0.58878 stdev: 0.08000
# Best fitness: 0.69419 - size: (3, 10) - species 5 - id 7562
# Average adjusted fitness: 0.085
# Mean genetic distance 2.769, standard deviation 0.725
# Population of 149 members in 8 species
# Total extinctions: 0
# Generation time: 1.410 sec (1.368 average)
#
#  ****** Running generation 59 ******
#
# Population's average fitness: 0.59436 stdev: 0.07437
# Best fitness: 0.69419 - size: (3, 10) - species 11 - id 7562
# Average adjusted fitness: 0.089
# Mean genetic distance 2.730, standard deviation 0.799
# Population of 149 members in 8 species
# Total extinctions: 0
# Generation time: 1.418 sec (1.375 average)
#
#  ****** Running generation 60 ******
#
# Population's average fitness: 0.59900 stdev: 0.07867
# Best fitness: 0.69419 - size: (3, 10) - species 11 - id 7562
# Average adjusted fitness: 0.093
# Mean genetic distance 2.737, standard deviation 0.768
# Population of 149 members in 8 species
# Total extinctions: 0
# Generation time: 1.363 sec (1.377 average)
#
#  ****** Running generation 61 ******
#
# Population's average fitness: 0.59217 stdev: 0.07582
# Best fitness: 0.69419 - size: (3, 10) - species 11 - id 7562
# Average adjusted fitness: 0.100
# Mean genetic distance 2.670, standard deviation 0.788
# Population of 150 members in 8 species
# Total extinctions: 0
# Generation time: 1.369 sec (1.378 average)
#
#  ****** Running generation 62 ******
#
# Population's average fitness: 0.59858 stdev: 0.07455
# Best fitness: 0.69419 - size: (3, 10) - species 11 - id 7562
# Average adjusted fitness: 0.103
# Mean genetic distance 2.668, standard deviation 0.811
# Population of 149 members in 8 species
# Total extinctions: 0
# Generation time: 1.368 sec (1.382 average)
#
#  ****** Running generation 63 ******
#
# Population's average fitness: 0.60184 stdev: 0.07774
# Best fitness: 0.69419 - size: (3, 10) - species 11 - id 7562
# Average adjusted fitness: 0.123
# Mean genetic distance 2.694, standard deviation 0.794
# Population of 151 members in 8 species
# Total extinctions: 0
# Generation time: 1.315 sec (1.374 average)
#
#  ****** Running generation 64 ******
#
# Population's average fitness: 0.58718 stdev: 0.07861
# Best fitness: 0.69425 - size: (2, 8) - species 11 - id 9175
# Average adjusted fitness: 0.134
# Mean genetic distance 2.611, standard deviation 0.800
# Population of 150 members in 8 species
# Total extinctions: 0
# Generation time: 1.368 sec (1.376 average)
#
#  ****** Running generation 65 ******
# Population's average fitness: 0.61886 stdev: 0.07200
# Best fitness: 0.69430 - size: (3, 7) - species 11 - id 9302
# Average adjusted fitness: 0.119
# Mean genetic distance 2.663, standard deviation 0.758
# Population of 149 members in 8 species
# Total extinctions: 0
# Generation time: 1.362 sec (1.374 average)
#
#  ****** Running generation 66 ******
#
# Population's average fitness: 0.59463 stdev: 0.08024
# Best fitness: 0.69430 - size: (3, 7) - species 11 - id 9302
# Average adjusted fitness: 0.166
# Mean genetic distance 2.577, standard deviation 0.759
# Population of 151 members in 8 species
# Total extinctions: 0
# Generation time: 1.304 sec (1.367 average)
#
#  ****** Running generation 67 ******
#
# Population's average fitness: 0.60524 stdev: 0.07830
# Best fitness: 0.69485 - size: (3, 6) - species 11 - id 9567
# Average adjusted fitness: 0.106
# Mean genetic distance 2.587, standard deviation 0.797
# Population of 150 members in 8 species
# Total extinctions: 0
# Generation time: 1.381 sec (1.366 average)
#
#  ****** Running generation 68 ******
#
# Population's average fitness: 0.59789 stdev: 0.08132
# Best fitness: 0.69485 - size: (3, 6) - species 11 - id 9567
# Average adjusted fitness: 0.098
# Mean genetic distance 2.576, standard deviation 0.796
# Population of 148 members in 8 species
# Total extinctions: 0
# Generation time: 1.347 sec (1.359 average)
#
#  ****** Running generation 69 ******
#
# Population's average fitness: 0.60008 stdev: 0.07978
# Best fitness: 0.69489 - size: (4, 8) - species 11 - id 9832
# Average adjusted fitness: 0.099
# Mean genetic distance 2.618, standard deviation 0.771
# Population of 149 members in 8 species
# Total extinctions: 0
# Generation time: 1.332 sec (1.351 average)
#
#  ****** Running generation 70 ******
#
# Population's average fitness: 0.60535 stdev: 0.07860
# Best fitness: 0.69556 - size: (3, 7) - species 11 - id 9969
# Average adjusted fitness: 0.102
# Mean genetic distance 2.640, standard deviation 0.812
# Population of 151 members in 8 species
# Total extinctions: 0
# Generation time: 1.357 sec (1.350 average)
#
#  ****** Running generation 71 ******
#
# Population's average fitness: 0.60730 stdev: 0.08263
# Best fitness: 0.69556 - size: (3, 7) - species 11 - id 9969
# Average adjusted fitness: 0.112
# Mean genetic distance 2.671, standard deviation 0.843
# Population of 150 members in 8 species
# Total extinctions: 0
# Generation time: 1.358 sec (1.349 average)
#
#  ****** Running generation 72 ******
#
# Population's average fitness: 0.60778 stdev: 0.07707
# Best fitness: 0.69556 - size: (3, 7) - species 11 - id 9969
# Average adjusted fitness: 0.107
# Mean genetic distance 2.760, standard deviation 0.854
# Population of 150 members in 8 species
# Total extinctions: 0
# Generation time: 1.373 sec (1.350 average)
#
#  ****** Running generation 73 ******
#
# Population's average fitness: 0.60312 stdev: 0.07680
# Best fitness: 0.69556 - size: (3, 7) - species 11 - id 9969
# Average adjusted fitness: 0.108
# Mean genetic distance 2.700, standard deviation 0.875
# Population of 152 members in 8 species
# Total extinctions: 0
# Generation time: 1.385 sec (1.357 average)
#
#  ****** Running generation 74 ******
#
# Population's average fitness: 0.60968 stdev: 0.07949
# Best fitness: 0.69556 - size: (3, 7) - species 11 - id 9969
# Average adjusted fitness: 0.108
# Mean genetic distance 2.776, standard deviation 0.902
# Population of 153 members in 8 species
# Total extinctions: 0
# Generation time: 1.409 sec (1.361 average)
#
# Best genome:
# Key: 9969
# Fitness: 0.6955626358118782
# Nodes:
# 	0 DefaultNodeGene(key=0, bias=-7.806559351165685, response=1.0, activation=sigmoid, aggregation=sum)
# 	961 DefaultNodeGene(key=961, bias=0.7606147433854114, response=1.0, activation=sigmoid, aggregation=sum)
# 	1858 DefaultNodeGene(key=1858, bias=-0.8882520067078313, response=1.0, activation=sigmoid, aggregation=sum)
# Connections:
# 	DefaultConnectionGene(key=(-11, 961), weight=-0.675143004995768, enabled=True)
# 	DefaultConnectionGene(key=(-10, 0), weight=-2.2155272738333793, enabled=True)
# 	DefaultConnectionGene(key=(-7, 0), weight=2.4488272310697923, enabled=True)
# 	DefaultConnectionGene(key=(-6, 961), weight=2.0164820447448966, enabled=True)
# 	DefaultConnectionGene(key=(-5, 0), weight=12.24035945523609, enabled=True)
# 	DefaultConnectionGene(key=(-4, 0), weight=0.5657435908890618, enabled=True)
# 	DefaultConnectionGene(key=(-3, 961), weight=-1.1871778088375358, enabled=False)
# 	DefaultConnectionGene(key=(961, 0), weight=0.7903385774123962, enabled=False)
# 	DefaultConnectionGene(key=(1858, 961), weight=-2.3322847377108635, enabled=True)
#
#
#  1600 1600
#
#
#
#  ****** Running generation 75 ******
#
# Population's average fitness: 0.60660 stdev: 0.08347
# Best fitness: 0.71094 - size: (3, 9) - species 11 - id 10651
# Average adjusted fitness: 0.112
# Mean genetic distance 2.723, standard deviation 0.851
# Population of 150 members in 8 species
# Total extinctions: 0
# Generation time: 2.758 sec (1.500 average)
#
#  ****** Running generation 76 ******
#
# Population's average fitness: 0.60486 stdev: 0.08360
# Best fitness: 0.71094 - size: (3, 9) - species 11 - id 10651
# Average adjusted fitness: 0.110
# Mean genetic distance 2.759, standard deviation 0.865
# Population of 149 members in 8 species
# Total extinctions: 0
# Generation time: 2.676 sec (1.638 average)
#
#  ****** Running generation 77 ******
#
# Population's average fitness: 0.60635 stdev: 0.08666
# Best fitness: 0.71147 - size: (3, 7) - species 11 - id 10908
# Average adjusted fitness: 0.150
# Mean genetic distance 2.759, standard deviation 0.890
# Population of 149 members in 8 species
# Total extinctions: 0
# Generation time: 2.628 sec (1.762 average)
#
#  ****** Running generation 78 ******
#
# Population's average fitness: 0.61625 stdev: 0.08631
# Best fitness: 0.71147 - size: (3, 7) - species 11 - id 10908
# Average adjusted fitness: 0.148
# Mean genetic distance 2.810, standard deviation 0.910
# Population of 150 members in 9 species
# Total extinctions: 0
# Generation time: 2.637 sec (1.891 average)
#
#  ****** Running generation 79 ******
#
# Population's average fitness: 0.62581 stdev: 0.08179
# Best fitness: 0.71147 - size: (3, 7) - species 11 - id 10908
# Average adjusted fitness: 0.118
# Mean genetic distance 2.696, standard deviation 0.883
# Population of 149 members in 9 species
# Total extinctions: 0
# Generation time: 2.695 sec (2.028 average)
#
#  ****** Running generation 80 ******
#
# Population's average fitness: 0.61331 stdev: 0.08402
# Best fitness: 0.71147 - size: (3, 7) - species 11 - id 10908
# Average adjusted fitness: 0.107
# Mean genetic distance 2.733, standard deviation 0.875
# Population of 150 members in 9 species
# Total extinctions: 0
# Generation time: 2.668 sec (2.159 average)
#
#  ****** Running generation 81 ******
#
# Population's average fitness: 0.61276 stdev: 0.08673
# Best fitness: 0.71147 - size: (3, 7) - species 11 - id 10908
# Average adjusted fitness: 0.107
# Mean genetic distance 2.770, standard deviation 0.820
# Population of 150 members in 9 species
# Total extinctions: 0
# Generation time: 2.702 sec (2.293 average)
#
#  ****** Running generation 82 ******
#
# Population's average fitness: 0.60828 stdev: 0.08443
# Best fitness: 0.71147 - size: (3, 7) - species 11 - id 10908
# Average adjusted fitness: 0.115
# Mean genetic distance 2.646, standard deviation 0.848
# Population of 150 members in 9 species
# Total extinctions: 0
# Generation time: 2.778 sec (2.434 average)
#
#  ****** Running generation 83 ******
#
# Population's average fitness: 0.60188 stdev: 0.08603
# Best fitness: 0.71233 - size: (3, 4) - species 5 - id 11701
# Average adjusted fitness: 0.114
# Mean genetic distance 2.656, standard deviation 0.864
# Population of 151 members in 9 species
# Total extinctions: 0
# Generation time: 2.626 sec (2.558 average)
#
#  ****** Running generation 84 ******
#
# Population's average fitness: 0.61526 stdev: 0.08569
# Best fitness: 0.71233 - size: (3, 4) - species 5 - id 11701
# Average adjusted fitness: 0.138
# Mean genetic distance 2.702, standard deviation 0.892
# Population of 149 members in 9 species
# Total extinctions: 0
# Generation time: 2.685 sec (2.685 average)
#
#  ****** Running generation 85 ******
#
# Population's average fitness: 0.60869 stdev: 0.08608
# Best fitness: 0.71233 - size: (3, 4) - species 5 - id 11701
# Average adjusted fitness: 0.115
# Mean genetic distance 2.636, standard deviation 0.907
# Population of 149 members in 9 species
# Total extinctions: 0
# Generation time: 2.662 sec (2.676 average)
#
#  ****** Running generation 86 ******
# Population's average fitness: 0.61868 stdev: 0.08299
# Best fitness: 0.71307 - size: (3, 5) - species 5 - id 12103
# Average adjusted fitness: 0.123
# Mean genetic distance 2.627, standard deviation 0.884
# Population of 149 members in 9 species
# Total extinctions: 0
# Generation time: 2.638 sec (2.672 average)
#
#  ****** Running generation 87 ******
#
# Population's average fitness: 0.61972 stdev: 0.08289
# Best fitness: 0.71307 - size: (3, 5) - species 5 - id 12103
# Average adjusted fitness: 0.124
# Mean genetic distance 2.719, standard deviation 0.934
# Population of 149 members in 10 species
# Total extinctions: 0
# Generation time: 2.629 sec (2.672 average)
#
#  ****** Running generation 88 ******
#
# Population's average fitness: 0.61686 stdev: 0.08717
# Best fitness: 0.71315 - size: (3, 6) - species 5 - id 12366
# Average adjusted fitness: 0.272
# Mean genetic distance 2.822, standard deviation 0.952
# Population of 149 members in 10 species
# Total extinctions: 0
# Generation time: 2.707 sec (2.679 average)
#
#  ****** Running generation 89 ******
#
# Population's average fitness: 0.60258 stdev: 0.08655
# Best fitness: 0.71315 - size: (3, 6) - species 5 - id 12366
# Average adjusted fitness: 0.120
# Mean genetic distance 2.767, standard deviation 0.912
# Population of 149 members in 10 species
# Total extinctions: 0
# Generation time: 2.654 sec (2.675 average)
#
#  ****** Running generation 90 ******
#
# Population's average fitness: 0.60013 stdev: 0.08743
# Best fitness: 0.71315 - size: (3, 6) - species 5 - id 12366
# Average adjusted fitness: 0.101
# Mean genetic distance 2.885, standard deviation 0.952
# Population of 150 members in 10 species
# Total extinctions: 0
# Generation time: 2.657 sec (2.674 average)
#
#  ****** Running generation 91 ******
#
# Population's average fitness: 0.61516 stdev: 0.08287
# Best fitness: 0.71315 - size: (3, 6) - species 5 - id 12366
# Average adjusted fitness: 0.116
# Mean genetic distance 2.881, standard deviation 0.923
# Population of 150 members in 10 species
# Total extinctions: 0
# Generation time: 2.726 sec (2.676 average)
#
#  ****** Running generation 92 ******
#
# Population's average fitness: 0.61350 stdev: 0.08291
# Best fitness: 0.71315 - size: (3, 6) - species 5 - id 12366
# Average adjusted fitness: 0.115
# Mean genetic distance 2.867, standard deviation 0.901
# Population of 149 members in 10 species
# Total extinctions: 0
# Generation time: 2.755 sec (2.674 average)
#
#  ****** Running generation 93 ******
#
# Population's average fitness: 0.61758 stdev: 0.08164
# Best fitness: 0.71315 - size: (3, 6) - species 5 - id 12366
# Average adjusted fitness: 0.132
# Mean genetic distance 2.839, standard deviation 0.924
# Population of 150 members in 10 species
# Total extinctions: 0
# Generation time: 2.768 sec (2.688 average)
#
#  ****** Running generation 94 ******
#
# Population's average fitness: 0.61495 stdev: 0.08336
# Best fitness: 0.71315 - size: (3, 6) - species 5 - id 12366
# Average adjusted fitness: 0.117
# Mean genetic distance 2.894, standard deviation 0.910
# Population of 151 members in 10 species
# Total extinctions: 0
# Generation time: 2.726 sec (2.692 average)
#
#  ****** Running generation 95 ******
#
# Population's average fitness: 0.60698 stdev: 0.08334
# Best fitness: 0.71315 - size: (3, 6) - species 5 - id 12366
# Average adjusted fitness: 0.115
# Mean genetic distance 2.900, standard deviation 0.913
# Population of 150 members in 10 species
# Total extinctions: 0
# Generation time: 2.757 sec (2.702 average)
#
#  ****** Running generation 96 ******
#
# Population's average fitness: 0.62078 stdev: 0.08194
# Best fitness: 0.71315 - size: (3, 6) - species 5 - id 12366
# Average adjusted fitness: 0.124
# Mean genetic distance 2.884, standard deviation 0.875
# Population of 152 members in 10 species
# Total extinctions: 0
# Generation time: 2.872 sec (2.725 average)
#
#  ****** Running generation 97 ******
#
# Population's average fitness: 0.61604 stdev: 0.08508
# Best fitness: 0.71315 - size: (3, 6) - species 5 - id 12366
# Average adjusted fitness: 0.143
# Mean genetic distance 2.915, standard deviation 0.862
# Population of 152 members in 10 species
# Total extinctions: 0
# Generation time: 2.912 sec (2.753 average)
#
#  ****** Running generation 98 ******
#
# Population's average fitness: 0.62015 stdev: 0.08525
# Best fitness: 0.71315 - size: (3, 6) - species 5 - id 12366
# Average adjusted fitness: 0.126
# Mean genetic distance 2.951, standard deviation 0.850
# Population of 150 members in 10 species
# Total extinctions: 0
# Generation time: 2.835 sec (2.766 average)
#
#  ****** Running generation 99 ******
#
# Population's average fitness: 0.61655 stdev: 0.08520
# Best fitness: 0.71315 - size: (3, 6) - species 5 - id 12366
# Average adjusted fitness: 0.140
# Mean genetic distance 2.931, standard deviation 0.844
# Population of 148 members in 10 species
# Total extinctions: 0
# Generation time: 2.876 sec (2.788 average)
#
#  ****** Running generation 100 ******
#
# Population's average fitness: 0.62133 stdev: 0.08605
# Best fitness: 0.71360 - size: (3, 6) - species 5 - id 13928
# Average adjusted fitness: 0.131
# Mean genetic distance 2.917, standard deviation 0.856
# Population of 149 members in 11 species
# Total extinctions: 0
# Generation time: 2.808 sec (2.804 average)
#
#  ****** Running generation 101 ******
#
# Population's average fitness: 0.61389 stdev: 0.08238
# Best fitness: 0.71360 - size: (3, 6) - species 5 - id 13928
# Average adjusted fitness: 0.110
# Mean genetic distance 2.902, standard deviation 0.840
# Population of 151 members in 11 species
# Total extinctions: 0
# Generation time: 2.822 sec (2.813 average)
#
#  ****** Running generation 102 ******
#
# Population's average fitness: 0.61432 stdev: 0.08496
# Best fitness: 0.71360 - size: (3, 6) - species 5 - id 13928
# Average adjusted fitness: 0.116
# Mean genetic distance 2.864, standard deviation 0.813
# Population of 149 members in 11 species
# Total extinctions: 0
# Generation time: 2.797 sec (2.817 average)
#
#  ****** Running generation 103 ******
#
# Population's average fitness: 0.61835 stdev: 0.08811
# Best fitness: 0.71360 - size: (3, 6) - species 5 - id 13928
# Average adjusted fitness: 0.160
# Mean genetic distance 2.813, standard deviation 0.766
# Population of 150 members in 11 species
# Total extinctions: 0
# Generation time: 2.721 sec (2.813 average)
#
#  ****** Running generation 104 ******
#
# Population's average fitness: 0.61675 stdev: 0.08598
# Best fitness: 0.71448 - size: (5, 9) - species 5 - id 14437
# Average adjusted fitness: 0.112
# Mean genetic distance 2.872, standard deviation 0.801
# Population of 151 members in 11 species
# Total extinctions: 0
# Generation time: 2.881 sec (2.828 average)
#
#  ****** Running generation 105 ******
#
# Population's average fitness: 0.60835 stdev: 0.08705
# Best fitness: 0.71448 - size: (5, 9) - species 5 - id 14437
# Average adjusted fitness: 0.109
# Mean genetic distance 2.856, standard deviation 0.810
# Population of 153 members in 12 species
# Total extinctions: 0
# Generation time: 2.741 sec (2.827 average)
#
#  ****** Running generation 106 ******
#
# Population's average fitness: 0.61610 stdev: 0.08533
# Best fitness: 0.71448 - size: (5, 9) - species 5 - id 14437
# Average adjusted fitness: 0.114
# Mean genetic distance 2.880, standard deviation 0.806
# Population of 153 members in 12 species
# Total extinctions: 0
# Generation time: 2.812 sec (2.821 average)
#
#  ****** Running generation 107 ******
#
# Population's average fitness: 0.61755 stdev: 0.08579
# Best fitness: 0.71448 - size: (5, 9) - species 5 - id 14437
# Average adjusted fitness: 0.159
# Mean genetic distance 2.805, standard deviation 0.770
# Population of 151 members in 12 species
# Total extinctions: 0
# Generation time: 2.785 sec (2.808 average)
#
#  ****** Running generation 108 ******
#
# Population's average fitness: 0.61742 stdev: 0.08306
# Best fitness: 0.71482 - size: (5, 9) - species 5 - id 14967
# Average adjusted fitness: 0.119
# Mean genetic distance 2.779, standard deviation 0.764
# Population of 150 members in 12 species
# Total extinctions: 0
# Generation time: 2.743 sec (2.799 average)
#
#  ****** Running generation 109 ******
#
# Population's average fitness: 0.61449 stdev: 0.08359
# Best fitness: 0.71482 - size: (5, 9) - species 5 - id 14967
# Average adjusted fitness: 0.119
# Mean genetic distance 2.724, standard deviation 0.785
# Population of 152 members in 12 species
# Total extinctions: 0
# Generation time: 2.731 sec (2.784 average)
#
#  ****** Running generation 110 ******
# Population's average fitness: 0.61485 stdev: 0.08526
# Best fitness: 0.71482 - size: (5, 9) - species 5 - id 14967
# Average adjusted fitness: 0.133
# Mean genetic distance 2.763, standard deviation 0.783
# Population of 153 members in 12 species
# Total extinctions: 0
# Generation time: 2.793 sec (2.783 average)
#
#  ****** Running generation 111 ******
#
# Population's average fitness: 0.62005 stdev: 0.08176
# Best fitness: 0.71482 - size: (5, 9) - species 5 - id 14967
# Average adjusted fitness: 0.126
# Mean genetic distance 2.811, standard deviation 0.803
# Population of 150 members in 12 species
# Total extinctions: 0
# Generation time: 2.817 sec (2.782 average)
#
#  ****** Running generation 112 ******
#
# Population's average fitness: 0.61288 stdev: 0.08581
# Best fitness: 0.71482 - size: (5, 9) - species 5 - id 14967
# Average adjusted fitness: 0.114
# Mean genetic distance 2.795, standard deviation 0.829
# Population of 147 members in 11 species
# Total extinctions: 0
# Generation time: 2.834 sec (2.786 average)
#
#  ****** Running generation 113 ******
#
# Population's average fitness: 0.60465 stdev: 0.08663
# Best fitness: 0.71482 - size: (5, 9) - species 5 - id 14967
# Average adjusted fitness: 0.111
# Mean genetic distance 2.786, standard deviation 0.834
# Population of 148 members in 11 species
# Total extinctions: 0
# Generation time: 2.606 sec (2.774 average)
#
#  ****** Running generation 114 ******
#
# Population's average fitness: 0.61917 stdev: 0.08737
# Best fitness: 0.71757 - size: (5, 9) - species 5 - id 15727
# Average adjusted fitness: 0.123
# Mean genetic distance 2.751, standard deviation 0.850
# Population of 148 members in 11 species
# Total extinctions: 0
# Generation time: 2.687 sec (2.755 average)
#
#  ****** Running generation 115 ******
#
# Population's average fitness: 0.60732 stdev: 0.08162
# Best fitness: 0.71757 - size: (5, 9) - species 5 - id 15727
# Average adjusted fitness: 0.112
# Mean genetic distance 2.763, standard deviation 0.824
# Population of 150 members in 12 species
# Total extinctions: 0
# Generation time: 2.631 sec (2.744 average)
#
#  ****** Running generation 116 ******
#
# Population's average fitness: 0.62894 stdev: 0.08107
# Best fitness: 0.71757 - size: (5, 9) - species 5 - id 15727
# Average adjusted fitness: 0.124
# Mean genetic distance 2.821, standard deviation 0.796
# Population of 150 members in 12 species
# Total extinctions: 0
# Generation time: 2.654 sec (2.728 average)
#
#  ****** Running generation 117 ******
#
# Population's average fitness: 0.60516 stdev: 0.08571
# Best fitness: 0.71757 - size: (5, 9) - species 5 - id 15727
# Average adjusted fitness: 0.116
# Mean genetic distance 2.739, standard deviation 0.800
# Population of 150 members in 12 species
# Total extinctions: 0
# Generation time: 2.746 sec (2.724 average)
#
#  ****** Running generation 118 ******
#
# Population's average fitness: 0.61636 stdev: 0.08394
# Best fitness: 0.71757 - size: (5, 9) - species 5 - id 15727
# Average adjusted fitness: 0.122
# Mean genetic distance 2.760, standard deviation 0.798
# Population of 150 members in 12 species
# Total extinctions: 0
# Generation time: 2.702 sec (2.720 average)
#
#  ****** Running generation 119 ******
#
# Population's average fitness: 0.61656 stdev: 0.08346
# Best fitness: 0.71757 - size: (5, 9) - species 5 - id 15727
# Average adjusted fitness: 0.120
# Mean genetic distance 2.734, standard deviation 0.776
# Population of 150 members in 12 species
# Total extinctions: 0
# Generation time: 2.770 sec (2.724 average)
#
#  ****** Running generation 120 ******
#
# Population's average fitness: 0.61364 stdev: 0.08768
# Best fitness: 0.71757 - size: (5, 9) - species 5 - id 15727
# Average adjusted fitness: 0.142
# Mean genetic distance 2.826, standard deviation 0.787
# Population of 151 members in 12 species
# Total extinctions: 0
# Generation time: 2.684 sec (2.713 average)
#
#  ****** Running generation 121 ******
#
# Population's average fitness: 0.62108 stdev: 0.08323
# Best fitness: 0.71757 - size: (5, 9) - species 5 - id 15727
# Average adjusted fitness: 0.133
# Mean genetic distance 2.810, standard deviation 0.801
# Population of 152 members in 12 species
# Total extinctions: 0
# Generation time: 2.779 sec (2.709 average)
#
#  ****** Running generation 122 ******
#
# Population's average fitness: 0.62453 stdev: 0.08187
# Best fitness: 0.71757 - size: (5, 9) - species 5 - id 15727
# Average adjusted fitness: 0.129
# Mean genetic distance 2.734, standard deviation 0.831
# Population of 151 members in 11 species
# Total extinctions: 0
# Generation time: 2.749 sec (2.701 average)
#
#  ****** Running generation 123 ******
#
# Population's average fitness: 0.61497 stdev: 0.08180
# Best fitness: 0.71757 - size: (5, 9) - species 5 - id 15727
# Average adjusted fitness: 0.112
# Mean genetic distance 2.766, standard deviation 0.848
# Population of 151 members in 11 species
# Total extinctions: 0
# Generation time: 2.647 sec (2.705 average)
#
#  ****** Running generation 124 ******
#
# Population's average fitness: 0.61148 stdev: 0.08584
# Best fitness: 0.71793 - size: (5, 9) - species 5 - id 16994
# Average adjusted fitness: 0.135
# Mean genetic distance 2.713, standard deviation 0.853
# Population of 151 members in 11 species
# Total extinctions: 0
# Generation time: 2.729 sec (2.709 average)
#
#  ****** Running generation 125 ******
#
# Population's average fitness: 0.62758 stdev: 0.08059
# Best fitness: 0.71793 - size: (5, 9) - species 5 - id 16994
# Average adjusted fitness: 0.127
# Mean genetic distance 2.766, standard deviation 0.871
# Population of 152 members in 11 species
# Total extinctions: 0
# Generation time: 2.681 sec (2.714 average)
#
#  ****** Running generation 126 ******
#
# Population's average fitness: 0.62263 stdev: 0.08557
# Best fitness: 0.71793 - size: (5, 9) - species 5 - id 16994
# Average adjusted fitness: 0.135
# Mean genetic distance 2.785, standard deviation 0.841
# Population of 150 members in 11 species
# Total extinctions: 0
# Generation time: 2.725 sec (2.721 average)
#
#  ****** Running generation 127 ******
#
# Population's average fitness: 0.61754 stdev: 0.08465
# Best fitness: 0.71928 - size: (5, 10) - species 5 - id 17380
# Average adjusted fitness: 0.122
# Mean genetic distance 2.761, standard deviation 0.780
# Population of 152 members in 11 species
# Total extinctions: 0
# Generation time: 2.690 sec (2.716 average)
#
#  ****** Running generation 128 ******
#
# Population's average fitness: 0.61664 stdev: 0.08579
# Best fitness: 0.71928 - size: (5, 10) - species 5 - id 17380
# Average adjusted fitness: 0.120
# Mean genetic distance 2.739, standard deviation 0.848
# Population of 150 members in 11 species
# Total extinctions: 0
# Generation time: 2.666 sec (2.712 average)
#
#  ****** Running generation 129 ******
# ...
# Best fitness: 0.71917 - size: (7, 12) - species 18 - id 27703
# Average adjusted fitness: 0.099
# Mean genetic distance 2.856, standard deviation 1.053
# Population of 148 members in 8 species
# Total extinctions: 0
# Generation time: 4.233 sec (4.255 average)
#
#  ****** Running generation 271 ******
#
# Population's average fitness: 0.62537 stdev: 0.08394
# Best fitness: 0.71917 - size: (7, 12) - species 18 - id 27703
# Average adjusted fitness: 0.115
# Mean genetic distance 2.909, standard deviation 1.000
# Population of 150 members in 8 species
# Total extinctions: 0
# Generation time: 4.470 sec (4.290 average)
#
#  ****** Running generation 272 ******
#
# Population's average fitness: 0.61284 stdev: 0.08744
# Best fitness: 0.71917 - size: (7, 12) - species 18 - id 27703
# Average adjusted fitness: 0.101
# Mean genetic distance 2.889, standard deviation 1.006
# Population of 151 members in 8 species
# Total extinctions: 0
# Generation time: 4.295 sec (4.295 average)
#
#  ****** Running generation 273 ******
#
# Population's average fitness: 0.62259 stdev: 0.08855
# Best fitness: 0.71917 - size: (7, 12) - species 18 - id 27703
# Average adjusted fitness: 0.109
# Mean genetic distance 2.898, standard deviation 1.032
# Population of 150 members in 8 species
# Total extinctions: 0
# Generation time: 4.326 sec (4.308 average)
#
#  ****** Running generation 274 ******
#
# Population's average fitness: 0.62694 stdev: 0.08501
# Best fitness: 0.71917 - size: (7, 12) - species 18 - id 27703
# Average adjusted fitness: 0.115
# Mean genetic distance 2.917, standard deviation 0.985
# Population of 149 members in 8 species
# Total extinctions: 0
# Generation time: 4.479 sec (4.332 average)
#
#  ****** Running generation 275 ******
# Population's average fitness: 0.62875 stdev: 0.08462
# Best fitness: 0.71917 - size: (7, 12) - species 18 - id 27703
# Average adjusted fitness: 0.128
# Mean genetic distance 2.938, standard deviation 1.023
# Population of 150 members in 8 species
# Total extinctions: 0
# Generation time: 4.539 sec (4.363 average)
#
#  ****** Running generation 276 ******
#
# Population's average fitness: 0.62701 stdev: 0.08531
# Best fitness: 0.71917 - size: (7, 12) - species 18 - id 27703
# Average adjusted fitness: 0.120
# Mean genetic distance 2.957, standard deviation 1.047
# Population of 150 members in 8 species
# Total extinctions: 0
# Generation time: 4.599 sec (4.385 average)
#
#  ****** Running generation 277 ******
#
# Population's average fitness: 0.61885 stdev: 0.08928
# Best fitness: 0.71917 - size: (7, 12) - species 18 - id 27703
# Average adjusted fitness: 0.114
# Mean genetic distance 2.943, standard deviation 1.119
# Population of 151 members in 8 species
# Total extinctions: 0
# Generation time: 4.413 sec (4.386 average)
#
#  ****** Running generation 278 ******
#
# Population's average fitness: 0.61609 stdev: 0.09138
# Best fitness: 0.71917 - size: (7, 12) - species 18 - id 27703
# Average adjusted fitness: 0.113
# Mean genetic distance 2.893, standard deviation 1.089
# Population of 152 members in 8 species
# Total extinctions: 0
# Generation time: 4.629 sec (4.420 average)
#
#  ****** Running generation 279 ******
#
# Population's average fitness: 0.62364 stdev: 0.08697
# Best fitness: 0.71917 - size: (7, 12) - species 18 - id 27703
# Average adjusted fitness: 0.118
# Mean genetic distance 2.847, standard deviation 1.053
# Population of 152 members in 8 species
# Total extinctions: 0
# Generation time: 4.713 sec (4.470 average)
#
#  ****** Running generation 280 ******
#
# Population's average fitness: 0.62984 stdev: 0.08468
# Best fitness: 0.71917 - size: (7, 12) - species 18 - id 27703
# Average adjusted fitness: 0.133
# Mean genetic distance 2.946, standard deviation 1.039
# Population of 152 members in 8 species
# Total extinctions: 0
# Generation time: 4.612 sec (4.507 average)
#
#  ****** Running generation 281 ******
#
# Population's average fitness: 0.61133 stdev: 0.09354
# Best fitness: 0.71917 - size: (7, 12) - species 18 - id 27703
# Average adjusted fitness: 0.107
# Mean genetic distance 2.961, standard deviation 0.989
# Population of 152 members in 8 species
# Total extinctions: 0
# Generation time: 4.556 sec (4.516 average)
#
#  ****** Running generation 282 ******
#
# Population's average fitness: 0.62991 stdev: 0.08908
# Best fitness: 0.71917 - size: (7, 12) - species 18 - id 27703
# Average adjusted fitness: 0.123
# Mean genetic distance 3.033, standard deviation 1.179
# Population of 151 members in 8 species
# Total extinctions: 0
# Generation time: 4.637 sec (4.550 average)
#
#  ****** Running generation 283 ******
#
# Population's average fitness: 0.62001 stdev: 0.09024
# Best fitness: 0.71917 - size: (7, 12) - species 18 - id 27703
# Average adjusted fitness: 0.137
# Mean genetic distance 2.981, standard deviation 1.193
# Population of 151 members in 8 species
# Total extinctions: 0
# Generation time: 4.385 sec (4.556 average)
#
#  ****** Running generation 284 ******
#
# Population's average fitness: 0.63068 stdev: 0.08717
# Best fitness: 0.71930 - size: (1, 3) - species 5 - id 37996
# Average adjusted fitness: 0.126
# Mean genetic distance 2.753, standard deviation 0.908
# Population of 153 members in 8 species
# Total extinctions: 0
# Generation time: 4.375 sec (4.546 average)
#
#  ****** Running generation 285 ******
#
# Population's average fitness: 0.62498 stdev: 0.08883
# Best fitness: 0.71963 - size: (1, 3) - species 5 - id 38150
# Average adjusted fitness: 0.118
# Mean genetic distance 2.923, standard deviation 0.993
# Population of 151 members in 9 species
# Total extinctions: 0
# Generation time: 4.453 sec (4.537 average)
#
#  ****** Running generation 286 ******
#
# Population's average fitness: 0.61821 stdev: 0.08742
# Best fitness: 0.71963 - size: (1, 3) - species 5 - id 38150
# Average adjusted fitness: 0.105
# Mean genetic distance 3.060, standard deviation 0.944
# Population of 153 members in 9 species
# Total extinctions: 0
# Generation time: 4.372 sec (4.515 average)
#
#  ****** Running generation 287 ******
#
# Population's average fitness: 0.61083 stdev: 0.09035
# Best fitness: 0.71963 - size: (1, 3) - species 5 - id 38150
# Average adjusted fitness: 0.151
# Mean genetic distance 3.032, standard deviation 1.051
# Population of 151 members in 9 species
# Total extinctions: 0
# Generation time: 4.576 sec (4.531 average)
#
#  ****** Running generation 288 ******
#
# Population's average fitness: 0.62087 stdev: 0.09004
# Best fitness: 0.71963 - size: (1, 3) - species 5 - id 38150
# Average adjusted fitness: 0.118
# Mean genetic distance 3.046, standard deviation 1.034
# Population of 151 members in 9 species
# Total extinctions: 0
# Generation time: 4.520 sec (4.520 average)
#
#  ****** Running generation 289 ******
#
# Population's average fitness: 0.61717 stdev: 0.08991
# Best fitness: 0.71963 - size: (1, 3) - species 5 - id 38150
# Average adjusted fitness: 0.113
# Mean genetic distance 3.079, standard deviation 0.996
# Population of 149 members in 9 species
# Total extinctions: 0
# Generation time: 4.457 sec (4.494 average)
#
#  ****** Running generation 290 ******
#
# Population's average fitness: 0.62092 stdev: 0.08926
# Best fitness: 0.71963 - size: (1, 3) - species 5 - id 38150
# Average adjusted fitness: 0.133
# Mean genetic distance 3.079, standard deviation 0.999
# Population of 149 members in 9 species
# Total extinctions: 0
# Generation time: 4.419 sec (4.475 average)
#
#  ****** Running generation 291 ******
#
# Population's average fitness: 0.61653 stdev: 0.08774
# Best fitness: 0.71963 - size: (1, 3) - species 5 - id 38150
# Average adjusted fitness: 0.104
# Mean genetic distance 3.157, standard deviation 1.101
# Population of 151 members in 9 species
# Total extinctions: 0
# Generation time: 4.300 sec (4.449 average)
#
#  ****** Running generation 292 ******
#
# Population's average fitness: 0.61793 stdev: 0.08673
# Best fitness: 0.71963 - size: (1, 3) - species 5 - id 38150
# Average adjusted fitness: 0.109
# Mean genetic distance 3.216, standard deviation 1.170
# Population of 151 members in 9 species
# Total extinctions: 0
# Generation time: 4.435 sec (4.429 average)
#
#  ****** Running generation 293 ******
#
# Population's average fitness: 0.60662 stdev: 0.09139
# Best fitness: 0.71963 - size: (1, 3) - species 5 - id 38150
# Average adjusted fitness: 0.099
# Mean genetic distance 3.267, standard deviation 1.381
# Population of 152 members in 9 species
# Total extinctions: 0
# Generation time: 4.484 sec (4.439 average)
#
#  ****** Running generation 294 ******
#
# Population's average fitness: 0.61384 stdev: 0.08666
# Best fitness: 0.71963 - size: (1, 3) - species 5 - id 38150
# Average adjusted fitness: 0.108
# Mean genetic distance 3.292, standard deviation 1.459
# Population of 151 members in 9 species
# Total extinctions: 0
# Generation time: 5.031 sec (4.505 average)
#
#  ****** Running generation 295 ******
#
# Population's average fitness: 0.61403 stdev: 0.09003
# Best fitness: 0.71963 - size: (1, 3) - species 5 - id 38150
# Average adjusted fitness: 0.110
# Mean genetic distance 3.443, standard deviation 1.525
# Population of 149 members in 10 species
# Total extinctions: 0
# Generation time: 4.392 sec (4.499 average)
#
#  ****** Running generation 296 ******
#
# Population's average fitness: 0.61574 stdev: 0.08938
# Best fitness: 0.71963 - size: (1, 3) - species 5 - id 38150
# Average adjusted fitness: 0.109
# Mean genetic distance 3.370, standard deviation 1.579
# Population of 152 members in 10 species
# Total extinctions: 0
# Generation time: 4.484 sec (4.510 average)
#
#  ****** Running generation 297 ******
#
# Population's average fitness: 0.61584 stdev: 0.08693
# Best fitness: 0.71982 - size: (1, 3) - species 5 - id 39749
# Average adjusted fitness: 0.117
# Mean genetic distance 3.439, standard deviation 1.560
# Population of 151 members in 10 species
# Total extinctions: 0
# Generation time: 4.523 sec (4.505 average)
#
#  ****** Running generation 298 ******
#
# Population's average fitness: 0.61664 stdev: 0.08859
# Best fitness: 0.71982 - size: (1, 3) - species 5 - id 39749
# Average adjusted fitness: 0.269
# Mean genetic distance 3.374, standard deviation 1.353
# Population of 149 members in 10 species
# Total extinctions: 0
# Generation time: 4.642 sec (4.517 average)
#
#  ****** Running generation 299 ******
# Population's average fitness: 0.61324 stdev: 0.08815
# Best fitness: 0.72001 - size: (1, 3) - species 5 - id 39996
# Average adjusted fitness: 0.114
# Mean genetic distance 3.284, standard deviation 1.314
# Population of 149 members in 10 species
# Total extinctions: 0
# Generation time: 4.683 sec (4.539 average)
#
#  ****** Running generation 300 ******
#
# Population's average fitness: 0.61786 stdev: 0.08741
# Best fitness: 0.72001 - size: (1, 3) - species 5 - id 39996
# Average adjusted fitness: 0.184
# Mean genetic distance 3.254, standard deviation 1.280
# Population of 148 members in 10 species
# Total extinctions: 0
# Generation time: 4.744 sec (4.572 average)
#
#  ****** Running generation 301 ******
#
# Population's average fitness: 0.62426 stdev: 0.08773
# Best fitness: 0.72001 - size: (1, 3) - species 5 - id 39996
# Average adjusted fitness: 0.117
# Mean genetic distance 3.257, standard deviation 1.338
# Population of 150 members in 10 species
# Total extinctions: 0
# Generation time: 4.909 sec (4.633 average)
#
#  ****** Running generation 302 ******
#
# Population's average fitness: 0.61626 stdev: 0.09005
# Best fitness: 0.72001 - size: (1, 3) - species 5 - id 39996
# Average adjusted fitness: 0.111
# Mean genetic distance 3.279, standard deviation 1.340
# Population of 149 members in 10 species
# Total extinctions: 0
# Generation time: 4.483 sec (4.637 average)
#
#  ****** Running generation 303 ******
#
# Population's average fitness: 0.60828 stdev: 0.08534
# Best fitness: 0.72001 - size: (1, 3) - species 5 - id 39996
# Average adjusted fitness: 0.099
# Mean genetic distance 3.276, standard deviation 1.423
# Population of 152 members in 9 species
# Total extinctions: 0
# Generation time: 4.885 sec (4.678 average)
#
#  ****** Running generation 304 ******
#
# Population's average fitness: 0.62204 stdev: 0.08638
# Best fitness: 0.72001 - size: (1, 3) - species 5 - id 39996
# Average adjusted fitness: 0.113
# Mean genetic distance 3.280, standard deviation 1.433
# Population of 150 members in 9 species
# Total extinctions: 0
# Generation time: 4.746 sec (4.649 average)
#
#  ****** Running generation 305 ******
#
# Population's average fitness: 0.62513 stdev: 0.08704
# Best fitness: 0.72001 - size: (1, 3) - species 5 - id 39996
# Average adjusted fitness: 0.118
# Mean genetic distance 3.258, standard deviation 1.371
# Population of 150 members in 9 species
# Total extinctions: 0
# Generation time: 4.319 sec (4.642 average)
#
#  ****** Running generation 306 ******
#
# Population's average fitness: 0.60850 stdev: 0.09019
# Best fitness: 0.72001 - size: (1, 3) - species 5 - id 39996
# Average adjusted fitness: 0.108
# Mean genetic distance 3.403, standard deviation 1.412
# Population of 148 members in 9 species
# Total extinctions: 0
# Generation time: 4.433 sec (4.637 average)
#
#  ****** Running generation 307 ******
#
# Population's average fitness: 0.61306 stdev: 0.08953
# Best fitness: 0.72001 - size: (1, 3) - species 5 - id 39996
# Average adjusted fitness: 0.108
# Mean genetic distance 3.331, standard deviation 1.326
# Population of 149 members in 9 species
# Total extinctions: 0
# Generation time: 4.791 sec (4.664 average)
#
#  ****** Running generation 308 ******
#
# Population's average fitness: 0.61964 stdev: 0.08892
# Best fitness: 0.72001 - size: (1, 3) - species 5 - id 39996
# Average adjusted fitness: 0.113
# Mean genetic distance 3.269, standard deviation 1.256
# Population of 149 members in 9 species
# Total extinctions: 0
# Generation time: 4.488 sec (4.648 average)
#
#  ****** Running generation 309 ******
#
# Population's average fitness: 0.60746 stdev: 0.09280
# Best fitness: 0.72001 - size: (1, 3) - species 5 - id 39996
# Average adjusted fitness: 0.113
# Mean genetic distance 3.276, standard deviation 1.285
# Population of 148 members in 9 species
# Total extinctions: 0
# Generation time: 4.549 sec (4.635 average)
#
#  ****** Running generation 310 ******
#
# Population's average fitness: 0.61272 stdev: 0.09132
# Best fitness: 0.72001 - size: (1, 3) - species 5 - id 39996
# Average adjusted fitness: 0.111
# Mean genetic distance 3.131, standard deviation 1.215
# Population of 149 members in 8 species
# Total extinctions: 0
# Generation time: 4.406 sec (4.601 average)
#
#  ****** Running generation 311 ******
#
# Population's average fitness: 0.61137 stdev: 0.09072
# Best fitness: 0.72001 - size: (1, 3) - species 5 - id 39996
# Average adjusted fitness: 0.140
# Mean genetic distance 3.118, standard deviation 1.174
# Population of 151 members in 8 species
# Total extinctions: 0
# Generation time: 4.248 sec (4.535 average)
#
#  ****** Running generation 312 ******
#
# Population's average fitness: 0.62843 stdev: 0.08727
# Best fitness: 0.72001 - size: (1, 3) - species 5 - id 39996
# Average adjusted fitness: 0.119
# Mean genetic distance 3.032, standard deviation 1.188
# Population of 152 members in 8 species
# Total extinctions: 0
# Generation time: 4.420 sec (4.529 average)
#
#  ****** Running generation 313 ******
#
# Population's average fitness: 0.62146 stdev: 0.08936
# Best fitness: 0.72001 - size: (1, 3) - species 5 - id 39996
# Average adjusted fitness: 0.116
# Mean genetic distance 3.066, standard deviation 1.249
# Population of 152 members in 8 species
# Total extinctions: 0
# Generation time: 4.446 sec (4.485 average)
#
#  ****** Running generation 314 ******
#
# Population's average fitness: 0.61731 stdev: 0.09180
# Best fitness: 0.72001 - size: (1, 3) - species 5 - id 39996
# Average adjusted fitness: 0.206
# Mean genetic distance 3.086, standard deviation 1.219
# Population of 151 members in 8 species
# Total extinctions: 0
# Generation time: 4.551 sec (4.465 average)
#
# Best genome:
# Key: 39996
# Fitness: 0.7200050775614145
# Nodes:
# 	0 DefaultNodeGene(key=0, bias=-11.399573386330086, response=1.0, activation=sigmoid, aggregation=sum)
# Connections:
# 	DefaultConnectionGene(key=(-9, 0), weight=-1.3834663624527022, enabled=False)
# 	DefaultConnectionGene(key=(-7, 0), weight=1.4690111343955623, enabled=True)
# 	DefaultConnectionGene(key=(-5, 0), weight=16.170851388148467, enabled=True)
# 	DefaultConnectionGene(key=(-1, 0), weight=5.378368700804102, enabled=True)
#
# Output:
#
# Training Accuracy: 0.7240625
#
# Testing Accuracy: 0.7182335140168268
#
# Total time: 1001.6407463550568 seconds
